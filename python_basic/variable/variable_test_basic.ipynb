# %%
# ===================================================================

# 문제 1

text = "Python Programming"

# text를 모두 대문자로 변환하세요.

# text를 모두 소문자로 변환하세요.

# -------------------------------------------------------------------

# 문제 2

sentence = "Python is fun. Python is powerful."

# "Python"이라는 단어가 처음 나타나는 위치를 출력하세요.

# "Python"이라는 단어가 몇 번 등장하는지 출력하세요.

# -------------------------------------------------------------------

# 문제 3

word = "   hello   "

# 공백을 제거한 문자열을 출력하세요.

# 왼쪽 공백만 제거하고, 오른쪽 공백만 제거한 결과를 각각 출력하세요.

# -------------------------------------------------------------------

# 문제 4

text = "apple,banana,cherry"

# text를 쉼표(,)를 기준으로 나눠 리스트로 변환하세요.

# 리스트를 다시 문자열로 변환하되, 각 단어 사이에 공백을 추가하세요.

# -------------------------------------------------------------------

# 문제 5

name = "Alice"
age = 25

# 포매팅을 사용해 다음 문자열을 출력하세요: "My name is Alice, and I am 25 years old."

# -------------------------------------------------------------------

# 문제 6

# print 를 한번만 사용하여 아래와같이 출력하세요.
# Hello
# World

# -------------------------------------------------------------------

# 문제 7

# "Name: Alice"와 "Age: 25"를 탭으로 구분하여 출력하세요.
# 결과 예시
# Name: Alice
# Age:  25

# -------------------------------------------------------------------

# 문제 8

# C:\Users\Alice라는 문자열을 출력하세요.

# -------------------------------------------------------------------

# 문제 9

# 다음의 문자열을 출력하세요.
# Python is fun!
#     Let's learn together.

# -------------------------------------------------------------------

# 문제 10

# 다음의 문자열을 출력하세요.
# 문자열 "It's Python!"을 출력하세요.

# -------------------------------------------------------------------

# 문제 11

x = 10
y = 20

# x와 y가 모두 15보다 큰지 확인하세요

# -------------------------------------------------------------------

# 문제 12

x = 10
y = 20

# x 또는 y 중 하나가 15보다 큰지 확인하세요.

# -------------------------------------------------------------------

# 문제 13

is_raining = True

# 비가 오지 않는 경우를 확인하세요.

# -------------------------------------------------------------------

# 문제 14

a = 5
b = 15

# a는 10보다 작고, b는 10보다 큰지 확인하세요.

# -------------------------------------------------------------------

# 문제 15

x = 10
y = 20
z = 30

# x와 y가 모두 15보다 작거나, z가 25보다 큰지 확인하세요.

# -------------------------------------------------------------------

# 문제 16

fruits = ["apple", "banana"]

# fruits 리스트에 "cherry"를 추가하세요.

# -------------------------------------------------------------------

# 문제 17

fruits = ["apple", "banana"]
new_fruits = ["cherry", "date"]

# new_fruits의 요소를 fruits에 추가하세요.

# -------------------------------------------------------------------

# 문제 18

numbers = [1, 2, 3]

# numbers 리스트를 복사하고, 복사본에 4를 추가하세요.

# -------------------------------------------------------------------

# 문제 19

nums = [5, 3, 8, 1]

# nums를 오름차순으로 정렬하세요.

# -------------------------------------------------------------------

# 문제 20

nums = [1, 3, 5, 8]

# nums를 반대로 뒤집으세요.

# ===================================================================

# 풀이

# 문제 1

print(text.upper())  # "PYTHON PROGRAMMING"
print(text.lower())  # "python programming"

# -------------------------------------------------------------------

# 문제 2

print(text.upper())  # "PYTHON PROGRAMMING"
print(text.lower())  # "python programming"

# -------------------------------------------------------------------

# 문제 3

print(word.strip())  # "hello"
print(word.lstrip())  # "hello   "
print(word.rstrip())  # "   hello"

# -------------------------------------------------------------------

# 문제 4

fruits = text.split(",")  # ["apple", "banana", "cherry"]
print(fruits)

joined = " ".join(fruits)  # "apple banana cherry"
print(joined)

# -------------------------------------------------------------------

# 문제 5

formatted = f"My name is {name}, and I am {age} years old."
print(formatted)  # "My name is Alice, and I am 25 years old."

# -------------------------------------------------------------------

# 문제 6

print("Hello\nWorld")

# -------------------------------------------------------------------

# 문제 7

print("Name:\tAlice\nAge:\t25")

# -------------------------------------------------------------------

# 문제 8

print("C:\\Users\\Alice")

# -------------------------------------------------------------------

# 문제 9

print("Python is fun!\n\tLet's learn together.")

# -------------------------------------------------------------------

# 문제 10

print("It\'s Python!")  # 또는 print('It\'s Python!')

# -------------------------------------------------------------------

# 문제 11

print(x > 15 and y > 15)  # False

# -------------------------------------------------------------------

# 문제 12

print(x > 15 or y > 15)  # True

# -------------------------------------------------------------------

# 문제 13

print(not is_raining)  # False

# -------------------------------------------------------------------

# 문제 14

print(a < 10 and b > 10)  # True

# -------------------------------------------------------------------

# 문제 15

print((x < 15 and y < 15) or z > 25)  # True

# -------------------------------------------------------------------

# 문제 16

fruits.append("cherry")
print(fruits)  # ["apple", "banana", "cherry"]

# -------------------------------------------------------------------?

# 문제 17

fruits.extend(new_fruits)
print(fruits)  # ["apple", "banana", "cherry", "date"]

# -------------------------------------------------------------------?

# 문제 18

copy_numbers = numbers.copy()
copy_numbers.append(4)
print(copy_numbers)  # [1, 2, 3, 4]
print(numbers)  # [1, 2, 3]

# -------------------------------------------------------------------?

# 문제 19

nums.sort()
print(nums)  # [1, 3, 5, 8]

# -------------------------------------------------------------------?

# 문제 20

nums.reverse()
print(nums)  # [8, 5, 3, 1]

# ===================================================================
