# %%
# ===================================================================

# 문제 1

text = "Welcome to Python Programming!"

# 문자열에서 모든 모음(a, e, i, o, u)을 대문자로 변환하고, 나머지는 소문자로 변환하세요.

# -------------------------------------------------------------------

# 문제 2

sentence = "Data science is fun, and data is powerful."

# "data"라는 단어가 대소문자 구분 없이 몇 번 등장하는지 출력하세요.

# -------------------------------------------------------------------

# 문제 3

text = "###Python ###"

# text에서 "#" 문자를 제거하고, 앞뒤 공백이 있다면 제거한 결과를 출력하세요.

# -------------------------------------------------------------------

# 문제 4

sentence = "Python is fun and powerful"

# 단어를 모두 역순으로 뒤집어 출력하세요. (예: "Python is fun and powerful" → "powerful and fun is Python")

# -------------------------------------------------------------------

# 문제 5

name = "Alice"
scores = {"math": 90, "science": 85, "english": 88}

# 이름과 각 과목 점수를 포함한 결과 문자열을 출력하세요:
# 코드 복사
# Alice's scores are:
# Math: 90
# Science: 85
# English: 88

# -------------------------------------------------------------------

# 문제 6

# 다음과 같은 표 형태를 출력하세요
# Name       Age
# Alice      25
# Bob        30

# -------------------------------------------------------------------

# 문제 7

path = "C:\\Users\\Documents\\python"

# 문자열에서 백슬래시를 제거하고, 슬래시(/)로 변환하여 출력하세요.

# -------------------------------------------------------------------

# 문제 8

x, y, z = 10, 20, 30

# x, y, z 중에서 두 값 이상이 15보다 큰지 확인하세요.

# -------------------------------------------------------------------

# 문제 9

numbers = [15, 8, 22, 5, 10]

# 리스트에서 10보다 큰 값이 모두 홀수인지 확인하세요.

# -------------------------------------------------------------------

# 문제 10

numbers = [1, 3, 5]

# 숫자 1부터 10까지를 순회하며, 홀수일 경우 리스트에 추가하세요.

# -------------------------------------------------------------------

# 문제 11

numbers = [3, 5, 7, 3, 9, 3]

# 리스트에서 모든 3을 제거하세요.

# -------------------------------------------------------------------

# 문제 12

original = [1, 2, 3]

# 복사본 리스트에 4를 추가하고, 원본 리스트는 변경하지 마세요.

# -------------------------------------------------------------------

# 문제 13

nums = [12, 4, 15, 8, 2]

# 리스트를 내림차순으로 정렬하세요.

# -------------------------------------------------------------------

# 문제 14

fruits = ["apple", "banana", "cherry"]

# 리스트에서 마지막 항목을 제거하고, 제거된 항목을 출력하세요.

# ===================================================================

# 풀이

# 문제 1

result = "".join([char.upper() if char in "aeiouAEIOU" else char.lower() for char in text])
print(result)  # "wElcOmE tO pythOn prOgrAmmIng!"

# -------------------------------------------------------------------

# 문제 2

count = sentence.lower().count("data")
print(count)  # 2

# -------------------------------------------------------------------

# 문제 3

cleaned = text.strip("#").strip()
print(cleaned)  # "Python"

# -------------------------------------------------------------------

# 문제 4

reversed_sentence = " ".join(sentence.split()[::-1])
print(reversed_sentence)  # "powerful and fun is Python"

# -------------------------------------------------------------------

# 문제 5

formatted = f"{name}'s scores are:\nMath: {scores['math']}\nScience: {scores['science']}\nEnglish: {scores['english']}"
print(formatted)

# -------------------------------------------------------------------

# 문제 6

print("Name\t\tAge\nAlice\t\t25\nBob\t\t30")

# -------------------------------------------------------------------

# 문제 7

converted_path = path.replace("\\", "/")
print(converted_path)  # "C:/Users/Documents/python"

# -------------------------------------------------------------------

# 문제 8

result = (x > 15 and y > 15) or (y > 15 and z > 15) or (x > 15 and z > 15)
print(result)  # True

# -------------------------------------------------------------------

# 문제 9

result = all(num % 2 != 0 for num in numbers if num > 10)
print(result)  # False (22는 짝수)

# -------------------------------------------------------------------

# 문제 10

for i in range(1, 11):
    if i % 2 != 0:
        numbers.append(i)
print(numbers)  # [1, 3, 5, 1, 3, 5, 7, 9]

# -------------------------------------------------------------------

# 문제 11

while 3 in numbers:
    numbers.remove(3)
print(numbers)  # [5, 7, 9]

# -------------------------------------------------------------------

# 문제 12

copy_list = original.copy()
copy_list.append(4)
print(copy_list)  # [1, 2, 3, 4]
print(original)  # [1, 2, 3]

# -------------------------------------------------------------------

# 문제 13

nums.sort(reverse=True)
print(nums)  # [15, 12, 8, 4, 2]

# -------------------------------------------------------------------

# 문제 14

removed_item = fruits.pop()
print(removed_item)  # "cherry"
print(fruits)  # ["apple", "banana"]

# ===================================================================
